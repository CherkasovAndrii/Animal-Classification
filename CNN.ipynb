# %% [markdown]
# # Importing dependencies and dataset

# %%
#import model building libraries
import numpy as np
import tensorflow as tf
import os as os
import matplotlib.pyplot as plt

from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K

# %% [markdown]
# # Model Building

# %%
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# Load the VGG16 model, excluding the top dense layers
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

# Freeze the layers of the base model
for layer in base_model.layers:
    layer.trainable = False

# Create the model
model = Sequential()

# Add the VGG16 base model
model.add(base_model)

# Add new layers for fine-tuning
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(5, activation='softmax'))

# Compile the model with a lower learning rate
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy', rmse])

# Early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, min_lr=0.00001)

# Data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Assuming you have directories 'dataset/training_set' and 'dataset/test_set'
train_generator = train_datagen.flow_from_directory(
    'animal-dataset/dataset/Training',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical'
)

validation_generator = test_datagen.flow_from_directory(
    'animal-dataset/dataset/Testing',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical'
)

# Train the model
history = model.fit(
    train_generator,
    epochs=250,
    validation_data=validation_generator,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Found 1526 images belonging to 5 classes.
# Found 407 images belonging to 5 classes.
# Epoch 1/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.2274 - loss: 1.9024 - rmse: 0.4241 - val_accuracy: 0.3022 - val_loss: 1.5011 - val_rmse: 0.3877 - learning_rate: 1.0000e-04
# Epoch 2/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.2650 - loss: 1.6132 - rmse: 0.3983 - val_accuracy: 0.4275 - val_loss: 1.4342 - val_rmse: 0.3801 - learning_rate: 1.0000e-04
# Epoch 3/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 0.3237 - loss: 1.5339 - rmse: 0.3912 - val_accuracy: 0.4570 - val_loss: 1.3841 - val_rmse: 0.3734 - learning_rate: 1.0000e-04
# Epoch 4/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 201ms/step - accuracy: 0.4032 - loss: 1.4270 - rmse: 0.3782 - val_accuracy: 0.6167 - val_loss: 1.2915 - val_rmse: 0.3617 - learning_rate: 1.0000e-04
# Epoch 5/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - accuracy: 0.3880 - loss: 1.4297 - rmse: 0.3796 - val_accuracy: 0.5602 - val_loss: 1.2539 - val_rmse: 0.3565 - learning_rate: 1.0000e-04
# Epoch 6/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - accuracy: 0.4061 - loss: 1.3839 - rmse: 0.3740 - val_accuracy: 0.6364 - val_loss: 1.1916 - val_rmse: 0.3475 - learning_rate: 1.0000e-04
# Epoch 7/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 0.4850 - loss: 1.3068 - rmse: 0.3635 - val_accuracy: 0.6511 - val_loss: 1.1404 - val_rmse: 0.3398 - learning_rate: 1.0000e-04
# Epoch 8/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.4594 - loss: 1.3131 - rmse: 0.3648 - val_accuracy: 0.6462 - val_loss: 1.0923 - val_rmse: 0.3332 - learning_rate: 1.0000e-04
# Epoch 9/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.4944 - loss: 1.2697 - rmse: 0.3591 - val_accuracy: 0.6708 - val_loss: 1.0405 - val_rmse: 0.3252 - learning_rate: 1.0000e-04
# Epoch 10/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.5126 - loss: 1.2284 - rmse: 0.3526 - val_accuracy: 0.6560 - val_loss: 1.0052 - val_rmse: 0.3186 - learning_rate: 1.0000e-04
# Epoch 11/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.5118 - loss: 1.2167 - rmse: 0.3515 - val_accuracy: 0.6830 - val_loss: 0.9604 - val_rmse: 0.3111 - learning_rate: 1.0000e-04
# Epoch 12/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - accuracy: 0.5460 - loss: 1.1669 - rmse: 0.3437 - val_accuracy: 0.6880 - val_loss: 0.9404 - val_rmse: 0.3078 - learning_rate: 1.0000e-04
# Epoch 13/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.5332 - loss: 1.1863 - rmse: 0.3477 - val_accuracy: 0.7076 - val_loss: 0.9138 - val_rmse: 0.3044 - learning_rate: 1.0000e-04
# Epoch 14/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.5501 - loss: 1.1121 - rmse: 0.3364 - val_accuracy: 0.6978 - val_loss: 0.8900 - val_rmse: 0.3005 - learning_rate: 1.0000e-04
# Epoch 15/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.5784 - loss: 1.1039 - rmse: 0.3350 - val_accuracy: 0.6978 - val_loss: 0.8676 - val_rmse: 0.2966 - learning_rate: 1.0000e-04
# Epoch 16/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 0.5803 - loss: 1.0882 - rmse: 0.3332 - val_accuracy: 0.7002 - val_loss: 0.8554 - val_rmse: 0.2941 - learning_rate: 1.0000e-04
# Epoch 17/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.5848 - loss: 1.0509 - rmse: 0.3270 - val_accuracy: 0.7101 - val_loss: 0.8556 - val_rmse: 0.2932 - learning_rate: 1.0000e-04
# Epoch 18/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.5749 - loss: 1.0423 - rmse: 0.3284 - val_accuracy: 0.7101 - val_loss: 0.8254 - val_rmse: 0.2883 - learning_rate: 1.0000e-04
# Epoch 19/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 0.5716 - loss: 1.0602 - rmse: 0.3302 - val_accuracy: 0.7297 - val_loss: 0.7985 - val_rmse: 0.2833 - learning_rate: 1.0000e-04
# Epoch 20/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.6169 - loss: 0.9949 - rmse: 0.3181 - val_accuracy: 0.7322 - val_loss: 0.7712 - val_rmse: 0.2793 - learning_rate: 1.0000e-04
# Epoch 21/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.6066 - loss: 1.0130 - rmse: 0.3225 - val_accuracy: 0.7518 - val_loss: 0.7684 - val_rmse: 0.2782 - learning_rate: 1.0000e-04
# Epoch 22/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.6386 - loss: 0.9673 - rmse: 0.3129 - val_accuracy: 0.7518 - val_loss: 0.7619 - val_rmse: 0.2754 - learning_rate: 1.0000e-04
# Epoch 23/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.6631 - loss: 0.9493 - rmse: 0.3105 - val_accuracy: 0.7346 - val_loss: 0.7714 - val_rmse: 0.2783 - learning_rate: 1.0000e-04
# Epoch 24/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.6237 - loss: 0.9580 - rmse: 0.3144 - val_accuracy: 0.7568 - val_loss: 0.7425 - val_rmse: 0.2721 - learning_rate: 1.0000e-04
# Epoch 25/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.6441 - loss: 0.9587 - rmse: 0.3135 - val_accuracy: 0.7518 - val_loss: 0.7403 - val_rmse: 0.2727 - learning_rate: 1.0000e-04
# Epoch 26/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.6324 - loss: 0.9219 - rmse: 0.3080 - val_accuracy: 0.7518 - val_loss: 0.7184 - val_rmse: 0.2678 - learning_rate: 1.0000e-04
# Epoch 27/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.6261 - loss: 0.9536 - rmse: 0.3144 - val_accuracy: 0.7592 - val_loss: 0.7096 - val_rmse: 0.2667 - learning_rate: 1.0000e-04
# Epoch 28/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.6473 - loss: 0.8950 - rmse: 0.3034 - val_accuracy: 0.7518 - val_loss: 0.6950 - val_rmse: 0.2638 - learning_rate: 1.0000e-04
# Epoch 29/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.6655 - loss: 0.8806 - rmse: 0.2999 - val_accuracy: 0.7617 - val_loss: 0.6951 - val_rmse: 0.2647 - learning_rate: 1.0000e-04
# Epoch 30/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.6441 - loss: 0.9312 - rmse: 0.3090 - val_accuracy: 0.7789 - val_loss: 0.6756 - val_rmse: 0.2600 - learning_rate: 1.0000e-04
# Epoch 31/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.6638 - loss: 0.8640 - rmse: 0.2970 - val_accuracy: 0.7690 - val_loss: 0.6832 - val_rmse: 0.2599 - learning_rate: 1.0000e-04
# Epoch 32/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - accuracy: 0.6568 - loss: 0.9081 - rmse: 0.3070 - val_accuracy: 0.7764 - val_loss: 0.6609 - val_rmse: 0.2564 - learning_rate: 1.0000e-04
# Epoch 33/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.6563 - loss: 0.8876 - rmse: 0.3022 - val_accuracy: 0.7740 - val_loss: 0.6515 - val_rmse: 0.2559 - learning_rate: 1.0000e-04
# Epoch 34/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.6962 - loss: 0.8431 - rmse: 0.2930 - val_accuracy: 0.7838 - val_loss: 0.6491 - val_rmse: 0.2548 - learning_rate: 1.0000e-04
# Epoch 35/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.6585 - loss: 0.8570 - rmse: 0.2957 - val_accuracy: 0.7690 - val_loss: 0.6626 - val_rmse: 0.2574 - learning_rate: 1.0000e-04
# Epoch 36/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.6994 - loss: 0.8124 - rmse: 0.2880 - val_accuracy: 0.7764 - val_loss: 0.6495 - val_rmse: 0.2525 - learning_rate: 1.0000e-04
# Epoch 37/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.6821 - loss: 0.8564 - rmse: 0.2972 - val_accuracy: 0.7838 - val_loss: 0.6376 - val_rmse: 0.2516 - learning_rate: 1.0000e-04
# Epoch 38/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.6583 - loss: 0.8496 - rmse: 0.3001 - val_accuracy: 0.7961 - val_loss: 0.6177 - val_rmse: 0.2480 - learning_rate: 1.0000e-04
# Epoch 39/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.6973 - loss: 0.8221 - rmse: 0.2901 - val_accuracy: 0.8034 - val_loss: 0.6110 - val_rmse: 0.2471 - learning_rate: 1.0000e-04
# Epoch 40/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.6870 - loss: 0.8296 - rmse: 0.2913 - val_accuracy: 0.7887 - val_loss: 0.6156 - val_rmse: 0.2473 - learning_rate: 1.0000e-04
# Epoch 41/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.7093 - loss: 0.7798 - rmse: 0.2816 - val_accuracy: 0.7912 - val_loss: 0.6006 - val_rmse: 0.2450 - learning_rate: 1.0000e-04
# Epoch 42/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.6703 - loss: 0.8242 - rmse: 0.2907 - val_accuracy: 0.8010 - val_loss: 0.6009 - val_rmse: 0.2437 - learning_rate: 1.0000e-04
# Epoch 43/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.6983 - loss: 0.8066 - rmse: 0.2884 - val_accuracy: 0.8084 - val_loss: 0.5950 - val_rmse: 0.2410 - learning_rate: 1.0000e-04
# Epoch 44/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.7052 - loss: 0.8048 - rmse: 0.2863 - val_accuracy: 0.7912 - val_loss: 0.6052 - val_rmse: 0.2462 - learning_rate: 1.0000e-04
# Epoch 45/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.6823 - loss: 0.8590 - rmse: 0.2945 - val_accuracy: 0.7985 - val_loss: 0.6025 - val_rmse: 0.2414 - learning_rate: 1.0000e-04
# Epoch 46/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.6960 - loss: 0.8016 - rmse: 0.2878 - val_accuracy: 0.8059 - val_loss: 0.5804 - val_rmse: 0.2408 - learning_rate: 1.0000e-04
# Epoch 47/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.6984 - loss: 0.7908 - rmse: 0.2859 - val_accuracy: 0.8206 - val_loss: 0.5642 - val_rmse: 0.2368 - learning_rate: 1.0000e-04
# Epoch 48/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.6909 - loss: 0.8022 - rmse: 0.2879 - val_accuracy: 0.8256 - val_loss: 0.5531 - val_rmse: 0.2291 - learning_rate: 1.0000e-04
# Epoch 49/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.7001 - loss: 0.7952 - rmse: 0.2855 - val_accuracy: 0.8256 - val_loss: 0.5487 - val_rmse: 0.2321 - learning_rate: 1.0000e-04
# Epoch 50/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.7016 - loss: 0.7742 - rmse: 0.2835 - val_accuracy: 0.8206 - val_loss: 0.5572 - val_rmse: 0.2341 - learning_rate: 1.0000e-04
# Epoch 51/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 9s 184ms/step - accuracy: 0.7210 - loss: 0.7690 - rmse: 0.2802 - val_accuracy: 0.8206 - val_loss: 0.5628 - val_rmse: 0.2344 - learning_rate: 1.0000e-04
# Epoch 52/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.6850 - loss: 0.7811 - rmse: 0.2866 - val_accuracy: 0.8157 - val_loss: 0.5522 - val_rmse: 0.2341 - learning_rate: 1.0000e-04
# Epoch 53/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.7116 - loss: 0.7652 - rmse: 0.2795 - val_accuracy: 0.8182 - val_loss: 0.5438 - val_rmse: 0.2306 - learning_rate: 1.0000e-04
# Epoch 54/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 9s 182ms/step - accuracy: 0.7233 - loss: 0.7408 - rmse: 0.2765 - val_accuracy: 0.8182 - val_loss: 0.5553 - val_rmse: 0.2303 - learning_rate: 1.0000e-04
# Epoch 55/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.7289 - loss: 0.7153 - rmse: 0.2727 - val_accuracy: 0.8206 - val_loss: 0.5458 - val_rmse: 0.2327 - learning_rate: 1.0000e-04
# Epoch 56/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.7236 - loss: 0.7443 - rmse: 0.2772 - val_accuracy: 0.8182 - val_loss: 0.5400 - val_rmse: 0.2309 - learning_rate: 1.0000e-04
# Epoch 57/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.6859 - loss: 0.7749 - rmse: 0.2842 - val_accuracy: 0.8329 - val_loss: 0.5228 - val_rmse: 0.2258 - learning_rate: 1.0000e-04
# Epoch 58/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.7173 - loss: 0.7444 - rmse: 0.2764 - val_accuracy: 0.8280 - val_loss: 0.5239 - val_rmse: 0.2284 - learning_rate: 1.0000e-04
# Epoch 59/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.7099 - loss: 0.7452 - rmse: 0.2769 - val_accuracy: 0.8256 - val_loss: 0.5256 - val_rmse: 0.2272 - learning_rate: 1.0000e-04
# Epoch 60/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 191ms/step - accuracy: 0.7073 - loss: 0.7686 - rmse: 0.2829 - val_accuracy: 0.8206 - val_loss: 0.5173 - val_rmse: 0.2246 - learning_rate: 1.0000e-04
# Epoch 61/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 191ms/step - accuracy: 0.7376 - loss: 0.6936 - rmse: 0.2679 - val_accuracy: 0.8452 - val_loss: 0.5055 - val_rmse: 0.2220 - learning_rate: 1.0000e-04
# Epoch 62/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 192ms/step - accuracy: 0.7405 - loss: 0.6768 - rmse: 0.2633 - val_accuracy: 0.8354 - val_loss: 0.5113 - val_rmse: 0.2232 - learning_rate: 1.0000e-04
# Epoch 63/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - accuracy: 0.7331 - loss: 0.7244 - rmse: 0.2713 - val_accuracy: 0.8452 - val_loss: 0.5070 - val_rmse: 0.2232 - learning_rate: 1.0000e-04
# Epoch 64/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.7321 - loss: 0.6865 - rmse: 0.2662 - val_accuracy: 0.8428 - val_loss: 0.4988 - val_rmse: 0.2194 - learning_rate: 1.0000e-04
# Epoch 65/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 192ms/step - accuracy: 0.7394 - loss: 0.7149 - rmse: 0.2738 - val_accuracy: 0.8354 - val_loss: 0.5075 - val_rmse: 0.2230 - learning_rate: 1.0000e-04
# Epoch 66/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.7295 - loss: 0.7312 - rmse: 0.2755 - val_accuracy: 0.8378 - val_loss: 0.5034 - val_rmse: 0.2221 - learning_rate: 1.0000e-04
# Epoch 67/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - accuracy: 0.7311 - loss: 0.7184 - rmse: 0.2723 - val_accuracy: 0.8501 - val_loss: 0.4936 - val_rmse: 0.2186 - learning_rate: 1.0000e-04
# Epoch 68/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 0.7615 - loss: 0.6810 - rmse: 0.2602 - val_accuracy: 0.8452 - val_loss: 0.4761 - val_rmse: 0.2179 - learning_rate: 1.0000e-04
# Epoch 69/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.7430 - loss: 0.6699 - rmse: 0.2634 - val_accuracy: 0.8477 - val_loss: 0.4852 - val_rmse: 0.2155 - learning_rate: 1.0000e-04
# Epoch 70/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.7292 - loss: 0.6699 - rmse: 0.2629 - val_accuracy: 0.8477 - val_loss: 0.4797 - val_rmse: 0.2163 - learning_rate: 1.0000e-04
# Epoch 71/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 203ms/step - accuracy: 0.7382 - loss: 0.6943 - rmse: 0.2672 - val_accuracy: 0.8477 - val_loss: 0.4847 - val_rmse: 0.2170 - learning_rate: 1.0000e-04
# Epoch 72/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 191ms/step - accuracy: 0.7189 - loss: 0.7030 - rmse: 0.2728 - val_accuracy: 0.8477 - val_loss: 0.4637 - val_rmse: 0.2128 - learning_rate: 1.0000e-04
# Epoch 73/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - accuracy: 0.7429 - loss: 0.6567 - rmse: 0.2616 - val_accuracy: 0.8526 - val_loss: 0.4818 - val_rmse: 0.2134 - learning_rate: 1.0000e-04
# Epoch 74/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - accuracy: 0.7405 - loss: 0.6738 - rmse: 0.2668 - val_accuracy: 0.8501 - val_loss: 0.4664 - val_rmse: 0.2131 - learning_rate: 1.0000e-04
# Epoch 75/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.7516 - loss: 0.6886 - rmse: 0.2685 - val_accuracy: 0.8501 - val_loss: 0.4603 - val_rmse: 0.2107 - learning_rate: 1.0000e-04
# Epoch 76/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 192ms/step - accuracy: 0.7469 - loss: 0.6789 - rmse: 0.2649 - val_accuracy: 0.8526 - val_loss: 0.4602 - val_rmse: 0.2117 - learning_rate: 1.0000e-04
# Epoch 77/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 194ms/step - accuracy: 0.7550 - loss: 0.6277 - rmse: 0.2554 - val_accuracy: 0.8501 - val_loss: 0.4741 - val_rmse: 0.2110 - learning_rate: 1.0000e-04
# Epoch 78/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 202ms/step - accuracy: 0.7640 - loss: 0.6696 - rmse: 0.2626 - val_accuracy: 0.8575 - val_loss: 0.4680 - val_rmse: 0.2101 - learning_rate: 1.0000e-04
# Epoch 79/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 194ms/step - accuracy: 0.7376 - loss: 0.6689 - rmse: 0.2633 - val_accuracy: 0.8452 - val_loss: 0.4580 - val_rmse: 0.2101 - learning_rate: 1.0000e-04
# Epoch 80/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - accuracy: 0.7474 - loss: 0.6826 - rmse: 0.2668 - val_accuracy: 0.8477 - val_loss: 0.4617 - val_rmse: 0.2104 - learning_rate: 1.0000e-04
# Epoch 81/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.7587 - loss: 0.6655 - rmse: 0.2623 - val_accuracy: 0.8501 - val_loss: 0.4523 - val_rmse: 0.2052 - learning_rate: 1.0000e-04
# Epoch 82/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 191ms/step - accuracy: 0.7598 - loss: 0.6148 - rmse: 0.2523 - val_accuracy: 0.8526 - val_loss: 0.4507 - val_rmse: 0.2078 - learning_rate: 1.0000e-04
# Epoch 83/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 191ms/step - accuracy: 0.7610 - loss: 0.6196 - rmse: 0.2538 - val_accuracy: 0.8649 - val_loss: 0.4521 - val_rmse: 0.2067 - learning_rate: 1.0000e-04
# Epoch 84/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.7375 - loss: 0.6453 - rmse: 0.2617 - val_accuracy: 0.8600 - val_loss: 0.4621 - val_rmse: 0.2125 - learning_rate: 1.0000e-04
# Epoch 85/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.7579 - loss: 0.6504 - rmse: 0.2606 - val_accuracy: 0.8526 - val_loss: 0.4479 - val_rmse: 0.2088 - learning_rate: 1.0000e-04
# Epoch 86/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.7469 - loss: 0.6651 - rmse: 0.2635 - val_accuracy: 0.8526 - val_loss: 0.4599 - val_rmse: 0.2108 - learning_rate: 1.0000e-04
# Epoch 87/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.7729 - loss: 0.6300 - rmse: 0.2543 - val_accuracy: 0.8600 - val_loss: 0.4615 - val_rmse: 0.2082 - learning_rate: 1.0000e-04
# Epoch 88/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.7746 - loss: 0.5814 - rmse: 0.2485 - val_accuracy: 0.8575 - val_loss: 0.4306 - val_rmse: 0.1998 - learning_rate: 1.0000e-04
# Epoch 89/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 192ms/step - accuracy: 0.7605 - loss: 0.6066 - rmse: 0.2499 - val_accuracy: 0.8550 - val_loss: 0.4481 - val_rmse: 0.2086 - learning_rate: 1.0000e-04
# Epoch 90/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 0.7963 - loss: 0.5397 - rmse: 0.2372 - val_accuracy: 0.8477 - val_loss: 0.4202 - val_rmse: 0.2007 - learning_rate: 1.0000e-04
# Epoch 91/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.7796 - loss: 0.5717 - rmse: 0.2441 - val_accuracy: 0.8501 - val_loss: 0.4386 - val_rmse: 0.2047 - learning_rate: 1.0000e-04
# Epoch 92/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - accuracy: 0.7716 - loss: 0.6007 - rmse: 0.2524 - val_accuracy: 0.8575 - val_loss: 0.4211 - val_rmse: 0.2018 - learning_rate: 1.0000e-04
# Epoch 93/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 0.7858 - loss: 0.5864 - rmse: 0.2471 - val_accuracy: 0.8575 - val_loss: 0.4298 - val_rmse: 0.2017 - learning_rate: 1.0000e-04
# Epoch 94/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 0.7552 - loss: 0.6047 - rmse: 0.2525 - val_accuracy: 0.8550 - val_loss: 0.4126 - val_rmse: 0.1991 - learning_rate: 1.0000e-04
# Epoch 95/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - accuracy: 0.7657 - loss: 0.6140 - rmse: 0.2515 - val_accuracy: 0.8526 - val_loss: 0.4183 - val_rmse: 0.1924 - learning_rate: 1.0000e-04
# Epoch 96/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 191ms/step - accuracy: 0.7704 - loss: 0.5943 - rmse: 0.2491 - val_accuracy: 0.8722 - val_loss: 0.4083 - val_rmse: 0.1935 - learning_rate: 1.0000e-04
# Epoch 97/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 0.7830 - loss: 0.5611 - rmse: 0.2409 - val_accuracy: 0.8673 - val_loss: 0.4099 - val_rmse: 0.1908 - learning_rate: 1.0000e-04
# Epoch 98/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 0.7903 - loss: 0.5687 - rmse: 0.2420 - val_accuracy: 0.8649 - val_loss: 0.4184 - val_rmse: 0.1963 - learning_rate: 1.0000e-04
# Epoch 99/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - accuracy: 0.8178 - loss: 0.5169 - rmse: 0.2306 - val_accuracy: 0.8722 - val_loss: 0.4093 - val_rmse: 0.1948 - learning_rate: 1.0000e-04
# Epoch 100/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 194ms/step - accuracy: 0.7996 - loss: 0.5951 - rmse: 0.2450 - val_accuracy: 0.8722 - val_loss: 0.4017 - val_rmse: 0.1945 - learning_rate: 1.0000e-04
# Epoch 101/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.7905 - loss: 0.5871 - rmse: 0.2448 - val_accuracy: 0.8722 - val_loss: 0.4113 - val_rmse: 0.1957 - learning_rate: 1.0000e-04
# Epoch 102/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.7975 - loss: 0.5858 - rmse: 0.2451 - val_accuracy: 0.8673 - val_loss: 0.4171 - val_rmse: 0.1974 - learning_rate: 1.0000e-04
# Epoch 103/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.7902 - loss: 0.5357 - rmse: 0.2392 - val_accuracy: 0.8649 - val_loss: 0.4107 - val_rmse: 0.1971 - learning_rate: 1.0000e-04
# Epoch 104/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 0.7772 - loss: 0.5928 - rmse: 0.2474 - val_accuracy: 0.8698 - val_loss: 0.3882 - val_rmse: 0.1924 - learning_rate: 1.0000e-04
# Epoch 105/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 192ms/step - accuracy: 0.7723 - loss: 0.5801 - rmse: 0.2451 - val_accuracy: 0.8649 - val_loss: 0.4172 - val_rmse: 0.1966 - learning_rate: 1.0000e-04
# Epoch 106/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.7831 - loss: 0.5564 - rmse: 0.2385 - val_accuracy: 0.8649 - val_loss: 0.3920 - val_rmse: 0.1903 - learning_rate: 1.0000e-04
# Epoch 107/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 194ms/step - accuracy: 0.7810 - loss: 0.6009 - rmse: 0.2498 - val_accuracy: 0.8624 - val_loss: 0.4350 - val_rmse: 0.2010 - learning_rate: 1.0000e-04
# Epoch 108/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.7635 - loss: 0.5929 - rmse: 0.2490 - val_accuracy: 0.8698 - val_loss: 0.3865 - val_rmse: 0.1876 - learning_rate: 1.0000e-04
# Epoch 109/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.7889 - loss: 0.5884 - rmse: 0.2448 - val_accuracy: 0.8747 - val_loss: 0.3877 - val_rmse: 0.1888 - learning_rate: 1.0000e-04
# Epoch 110/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.7723 - loss: 0.6105 - rmse: 0.2493 - val_accuracy: 0.8747 - val_loss: 0.3849 - val_rmse: 0.1883 - learning_rate: 1.0000e-04
# Epoch 111/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - accuracy: 0.7922 - loss: 0.5616 - rmse: 0.2432 - val_accuracy: 0.8747 - val_loss: 0.4127 - val_rmse: 0.1925 - learning_rate: 1.0000e-04
# Epoch 112/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 196ms/step - accuracy: 0.7762 - loss: 0.5706 - rmse: 0.2453 - val_accuracy: 0.8747 - val_loss: 0.4027 - val_rmse: 0.1932 - learning_rate: 1.0000e-04
# Epoch 113/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - accuracy: 0.7832 - loss: 0.5718 - rmse: 0.2435 - val_accuracy: 0.8771 - val_loss: 0.3736 - val_rmse: 0.1839 - learning_rate: 1.0000e-04
# Epoch 114/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.8018 - loss: 0.5502 - rmse: 0.2388 - val_accuracy: 0.8747 - val_loss: 0.3809 - val_rmse: 0.1875 - learning_rate: 1.0000e-04
# Epoch 115/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 0.8038 - loss: 0.5379 - rmse: 0.2366 - val_accuracy: 0.8747 - val_loss: 0.3689 - val_rmse: 0.1864 - learning_rate: 1.0000e-04
# Epoch 116/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 204ms/step - accuracy: 0.8064 - loss: 0.5190 - rmse: 0.2316 - val_accuracy: 0.8747 - val_loss: 0.3693 - val_rmse: 0.1830 - learning_rate: 1.0000e-04
# Epoch 117/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - accuracy: 0.7984 - loss: 0.5676 - rmse: 0.2414 - val_accuracy: 0.8722 - val_loss: 0.3697 - val_rmse: 0.1847 - learning_rate: 1.0000e-04
# Epoch 118/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 201ms/step - accuracy: 0.8125 - loss: 0.5266 - rmse: 0.2308 - val_accuracy: 0.8722 - val_loss: 0.3702 - val_rmse: 0.1889 - learning_rate: 1.0000e-04
# Epoch 119/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.8037 - loss: 0.5321 - rmse: 0.2356 - val_accuracy: 0.8796 - val_loss: 0.3566 - val_rmse: 0.1836 - learning_rate: 1.0000e-04
# Epoch 120/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.8031 - loss: 0.5415 - rmse: 0.2357 - val_accuracy: 0.8698 - val_loss: 0.3588 - val_rmse: 0.1840 - learning_rate: 1.0000e-04
# Epoch 121/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.7955 - loss: 0.5500 - rmse: 0.2400 - val_accuracy: 0.8821 - val_loss: 0.3646 - val_rmse: 0.1802 - learning_rate: 1.0000e-04
# Epoch 122/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.8160 - loss: 0.5050 - rmse: 0.2267 - val_accuracy: 0.8747 - val_loss: 0.3590 - val_rmse: 0.1839 - learning_rate: 1.0000e-04
# Epoch 123/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - accuracy: 0.8161 - loss: 0.5091 - rmse: 0.2298 - val_accuracy: 0.8673 - val_loss: 0.3633 - val_rmse: 0.1809 - learning_rate: 1.0000e-04
# Epoch 124/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.8098 - loss: 0.5337 - rmse: 0.2346 - val_accuracy: 0.8796 - val_loss: 0.3729 - val_rmse: 0.1855 - learning_rate: 1.0000e-04
# Epoch 125/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 191ms/step - accuracy: 0.8225 - loss: 0.5259 - rmse: 0.2304 - val_accuracy: 0.8747 - val_loss: 0.3684 - val_rmse: 0.1773 - learning_rate: 1.0000e-04
# Epoch 126/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - accuracy: 0.7992 - loss: 0.5030 - rmse: 0.2306 - val_accuracy: 0.8821 - val_loss: 0.3646 - val_rmse: 0.1787 - learning_rate: 1.0000e-04
# Epoch 127/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.8004 - loss: 0.4869 - rmse: 0.2274 - val_accuracy: 0.8845 - val_loss: 0.3734 - val_rmse: 0.1821 - learning_rate: 1.0000e-04
# Epoch 128/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - accuracy: 0.8146 - loss: 0.5093 - rmse: 0.2306 - val_accuracy: 0.8821 - val_loss: 0.3676 - val_rmse: 0.1813 - learning_rate: 1.0000e-04
# Epoch 129/250
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 201ms/step - accuracy: 0.8195 - loss: 0.4839 - rmse: 0.2257 - val_accuracy: 0.8821 - val_loss: 0.3612 - val_rmse: 0.1822 - learning_rate: 1.0000e-04

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Plot training & validation RMSE values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['rmse'])
plt.plot(history.history['val_rmse'])
plt.title('Model RMSE')
plt.ylabel('RMSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
# Save our model
model.save("animal_upd_250_cats_added_3.keras")

# %% [markdown]
# # Tesing the Model

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

import numpy as np

# Load the model
model = load_model("animal_upd_250_cats_added_3.keras", compile=False)

# Assuming you have defined your data generators earlier
# train_generator and validation_generator

# Get class indices
class_indices = train_generator.class_indices
class_names = list(class_indices.keys())
print(class_indices)
print(class_names)
# Function to preprocess the image and make predictions
def predict_image(img_path):
    # Load the image
    img = image.load_img(img_path, target_size=(64, 64))
    
    # Preprocess the image
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x /= 255.0  # Rescale the image as you did during training

    # Make a prediction
    pred = model.predict(x)
    predicted_class_index = np.argmax(pred)

    # Map predicted index to class name
    class_name = class_names[predicted_class_index]
    
    print("Predicted class index:", predicted_class_index)
    print("Predicted class:", class_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 13
#       7 model = load_model("animal_upd_250_cats_added_3.keras", compile=False)
#       9 # Assuming you have defined your data generators earlier
#      10 # train_generator and validation_generator
#      11
#      12 # Get class indices
# ---> 13 class_indices = train_generator.class_indices
#      14 class_names = list(class_indices.keys())
#      15 print(class_indices)
#
# NameError: name 'train_generator' is not defined

# %%
print("\nElephants: \n")

predict_image("test/elephant1.jpeg")
predict_image("test/elephant2.jpg")
predict_image("test/elephant3.jpeg")
predict_image("test/elephant4.jpeg")
predict_image("test/elephant5.jpeg")
predict_image("test/elephant6.jpeg")


print("\nBears: \n")
predict_image("test/bear1.jpg")
predict_image("test/bear2.jpeg")
predict_image("test/bear3.jpg")
predict_image("test/bear4.jpeg")
predict_image("test/bear5.jpeg")

print("\nCrows: \n")

predict_image("test/crow1.jpg")
predict_image("test/crow2.jpg")
predict_image("test/crow3.jpg")
predict_image("test/crow4.jpg")
predict_image("test/crow5.jpg")

print("\nRats: \n")

predict_image("test/rat1.jpeg")
predict_image("test/rat2.jpeg")
predict_image("test/rat3.jpeg")
predict_image("test/rat4.jpeg")
predict_image("test/rat5.jpeg")

print("\nCats: \n")

predict_image("test/cat1.jpg")
predict_image("test/cat2.jpg")
predict_image("test/cat3.jpg")
predict_image("test/cat4.jpg")
predict_image("test/cat5.jpg")
# Out:
# Elephants:
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# Predicted class index: 3
# Predicted class: elephants
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted class index: 3
# Predicted class: elephants
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted class index: 0
# Predicted class: bears
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted class index: 3
# Predicted class: elephants
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted class index: 3
# Predicted class: elephants
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted class index: 3
# Predicted class: elephants
#
# Bears:
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted class index: 0
# Predicted class: bears
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted class index: 0
# Predicted class: bears
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted class index: 0
# Predicted class: bears
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted class index: 0
# Predicted class: bears
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted class index: 0
# Predicted class: bears
#
# Crows:
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted class index: 2
# Predicted class: crows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted class index: 2
# Predicted class: crows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted class index: 2
# Predicted class: crows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted class index: 2
# Predicted class: crows
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted class index: 2
# Predicted class: crows
#
# Rats:
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted class index: 4
# Predicted class: rats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted class index: 4
# Predicted class: rats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Predicted class index: 4
# Predicted class: rats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted class index: 4
# Predicted class: rats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted class index: 4
# Predicted class: rats
#
# Cats:
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted class index: 4
# Predicted class: rats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted class index: 1
# Predicted class: cats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted class index: 1
# Predicted class: cats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted class index: 1
# Predicted class: cats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted class index: 1
# Predicted class: cats
